# %%
import pandas as pd

df = pd.read_csv('data/nyc_weather_dirty.csv')
df.isna().sum()
df.columns = ['date and time', 'temperature', 'humidity','wind speed', 'cloud cover','amount of precipitation']
df.head()
# Out:
#          date and time  temperature   humidity  wind speed cloud cover  \
# 0  2019-01-01 00:00:00     8.700000  97.000000   16.100000       100%.
# 1  2019-01-01 03:00:00    12.366667  94.333333   26.600000       100%.
# 2  2019-01-01 06:00:00    13.600000  90.000000   29.633333   70 – 80%.
# 3  2019-01-01 09:00:00    13.933333  74.333333   32.400000       100%.
# 4  2019-01-01 12:00:00    11.500000  60.333333   33.400000   70 – 80%.
#
#   amount of precipitation
# 0                     7.1
# 1                     0.4
# 2                     0.0
# 3                     0.0
# 4                     0.0

# %%
df['cloud cover'].value_counts()
# Out:
# cloud cover
# 100%.           99
# no clouds       55
# 70 – 80%.       36
# 20–30%.         28
# 50%.            22
# ??               1
# weird_value1     1
# undefined        1
# broken_data      1
# Name: count, dtype: int64

# %%
df.to_csv('data/nyc_weather_missing_values.csv', index=False)
